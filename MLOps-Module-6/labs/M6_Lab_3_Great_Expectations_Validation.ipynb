# %% [markdown]
# # M6 · Lab 3 — Great Expectations Data Validation
# ### Module 6 — Monitoring, Testing & Drift Detection | Spine Project: Truck Delay Classification
#
# | | |
# |---|---|
# | **Duration** | 60 min |
# | **Difficulty** | Intermediate |
# | **Tools** | Python 3.12.10, `great-expectations>=0.18,<1.0`, pandas |
# | **AWS** | None (local notebook — Lab 4 wires GE's pass/fail into SNS) |
# | **Prerequisite** | Lab 2 (same `data/` folder with the real M3 reference frame) |
# | **Builds toward** | Lab 4 + Lab 5 (combined pipeline runs GE → Evidently → SNS) |
# | **Cost** | ₹0 — all local |
#
# ---
# Lab 2 caught **statistical** drift. This lab catches **schema** breaks — corrupted values, NULL spikes, type changes,
# out-of-range numbers. Drift is gradual and probabilistic; schema breaks are sudden and binary. Production needs **both**.

# %% [markdown]
# ## 💻 Where to run this — SageMaker (recommended in class), Colab, or local
#
# **In class: the SageMaker Notebook Instance your instructor provisioned** (`m6-truck-delay-monitoring`). Everything is
# pre-installed (`evidently`, `great-expectations`, `xgboost`) and the real `data/` folder is already there — just open this
# notebook and run.
# - **Kernel:** `conda_python3`
# - **Data:** `data/reference/final_features.csv` + `data/artifacts/` ship with the labs on the instance (the `M6_DATA_DIR` default is `data`).
# - **Auto-stop:** the instance stops itself after ~45 min idle to save cost — your work, installed packages, and saved
#   artifacts persist on the EBS volume. Just hit **Start** the next day; **M7 and M8 reuse this same instance.**
# - **AWS access (Labs 4/5):** the instance's IAM role already grants `sns:Publish`, so there are **no access keys to configure.**
#
# **Portable fallback (self-paced / post-course):** this notebook also runs on **Google Colab** or **local Jupyter** — the
# setup cell below detects the environment and pip-installs what's missing. On Colab, upload the `data/` folder (or set
# `M6_DATA_DIR`). Locally, use **Python 3.12.10**. The data + model are the *real* M3 artifacts either way — nothing synthetic.

# %% [markdown]
# ## Learning Objectives
# 1. Explain what **Great Expectations (GE)** solves and where the GE/Evidently line sits.
# 2. Auto-profile the **real** reference frame into a starting **expectation suite**.
# 3. Hand-edit the suite to add domain rules the profiler can't infer.
# 4. Validate a **clean** batch (100% pass) and a **corrupted** batch (specific row-level failures).
# 5. Emit a structured failure payload + generate **Data Docs** (the team's "what must the data look like?" contract).

# %% [markdown]
# ## Business Context
# A month into production, the upstream scheduling service started emitting `route_id` as the string `"R-04522"` instead
# of the integer `4522`. The Truck Delay app didn't crash — it coerced the bad value to NaN, produced a low-confidence
# prediction, and operations treated it as "on time". **Three days of misrouted dispatches** before anyone joined the dots.
#
# That's **not drift** — a column of NaNs has no distribution to compare. It's a **schema break**, and it needs *declarative
# validation*: you write down "`truck_age` is an integer in [1, 30]" and every incoming batch is checked against the
# contract. One violating value fails the batch — loudly, with a row-level message — before the bad data reaches the model.

# %% [markdown]
# ## Prerequisites — the **real** M3 reference frame (no synthetic data)
# Same `data/` folder as Lab 2. We profile the genuine training distribution — **`data/reference/final_features.csv`**
# (12,308 × 37, regenerated from M3 Lab B and round-trip-validated against the model). The *only* synthetic thing here is
# the deliberately **corrupted batch** in Step 7 — you can't demonstrate catching corruption without some.
#
# > **Why pin GE `<1.0`?** GE v1.0 (Sep 2024) is a breaking rewrite. The course — and the Lab 5 production pipeline that
# > consumes this suite — uses the stable **0.18** line. Once you know 0.18, migrating to v1 is a half-day.

# %%
# ── Environment setup (Colab or local) ────────────────────────────────────────
import sys, subprocess, os
def _pip(*p): subprocess.run([sys.executable, "-m", "pip", "install", "-q", *p], check=True)
try:
    import great_expectations as gx
    print("great_expectations:", gx.__version__)
except ImportError:
    print("Installing great-expectations 0.18 …")
    _pip("great-expectations>=0.18,<1.0", "pandas==2.2.0", "numpy<2.0")
    import great_expectations as gx
    print("great_expectations:", gx.__version__)
# Out:
# Installing great-expectations 0.18 …
# great_expectations: 0.18.22

# %%
# ── Imports + load the real reference frame ───────────────────────────────────
import json
import numpy as np
import pandas as pd

DATA_DIR = os.environ.get("M6_DATA_DIR", "data")
REF_CSV  = os.path.join(DATA_DIR, "reference", "final_features.csv")
assert os.path.exists(REF_CSV), f"Real reference frame missing at {REF_CSV} (copy Module 6/labs/data/ next to this notebook)."

ref = pd.read_csv(REF_CSV)
print(f"Reference frame: {ref.shape}  (expected 12308 x 37)")
ref.head(3)
# Out:
# Reference frame: (12308, 37)  (expected 12308 x 37)
#    route_avg_temp  route_avg_wind_speed  route_avg_precip  route_avg_humidity  \
# 0           31.00                  4.25               0.0               86.00
# 1           43.25                  9.25               0.0               78.50
# 2           24.00                  7.00               0.0               63.75
#
#    route_avg_visibility  route_avg_pressure  origin_avg_temp  \
# 0                   6.0             1009.50        26.041667
# 1                   6.0             1021.25        26.041667
# 2                   5.5             1019.75        26.041667
#
#    origin_avg_wind_speed  origin_avg_precip  origin_avg_humidity  ...  \
# 0                   10.5                0.0               80.625  ...
# 1                   10.5                0.0               80.625  ...
# 2                   10.5                0.0               80.625  ...
#
#    route_description  origin_description  dest_description  accident  \
# 0              Clear          Light snow          Overcast         0
# 1      Partly cloudy          Light snow             Sunny         1
# 2              Clear          Light snow     Moderate snow         0
#
#    fuel_type  gender  driving_style  ratings  is_midnight  delay
# 0     diesel    male      proactive        7            0      0
# 1     diesel    male      proactive        8            1      0
# 2     diesel    male      proactive        8            0      0
#
# [3 rows x 37 columns]

# %% [markdown]
# ## Step 1 · Concepts — what's an "Expectation"?
# A single **expectation** is one assertion about a column:
# ```python
# expect_column_values_to_be_between("truck_age", min_value=1, max_value=30)
# ```
# There are ~50 built-ins:
#
# | Category | Example | Checks |
# |---|---|---|
# | Schema | `expect_column_to_exist` | the column is present |
# | Type | `expect_column_values_to_be_of_type` | int / float / str |
# | Range | `expect_column_values_to_be_between` | min/max bounds |
# | Set | `expect_column_values_to_be_in_set` | value ∈ enum |
# | Null | `expect_column_values_to_not_be_null` | NULL rate (`mostly=0.99`) |
# | Cardinality | `expect_column_distinct_values_to_be_in_set` | exact allowed set |
#
# An **expectation suite** is a JSON file of dozens of these. A **checkpoint** runs a suite against new data.
# Flow: **profile → edit → validate → publish**.

# %% [markdown]
# ## Step 2 · Create a file-backed GE project + register the reference as a runtime batch

# %%
from great_expectations.data_context import FileDataContext
from great_expectations.core.batch import RuntimeBatchRequest

# Creates ./great_expectations/ (committable) the first time; loads it thereafter.
try:
    context = FileDataContext.create(project_root_dir=".")
except Exception:
    context = gx.get_context(context_root_dir="./great_expectations")
print("GE project root:", context.root_directory)

# A runtime datasource lets us validate in-memory pandas DataFrames (the production pattern).
if "truck_delay_runtime" not in [ds["name"] for ds in context.list_datasources()]:
    context.add_datasource(
        name="truck_delay_runtime",
        class_name="Datasource",
        execution_engine={"class_name": "PandasExecutionEngine"},
        data_connectors={
            "default_runtime_data_connector_name": {
                "class_name": "RuntimeDataConnector",
                "batch_identifiers": ["default_identifier_name"],
            }
        },
    )
print("Datasources:", [ds["name"] for ds in context.list_datasources()])
# Out:
# GE project root: c:\Users\prash\OneDrive\2026\Training\K21Academy\MLOps\Module 6\labs\gx
# Datasources: ['truck_delay_runtime']

# %% [markdown]
# ## Step 3 · Auto-profile the reference frame into a starting suite

# %%
from great_expectations.profile.user_configurable_profiler import UserConfigurableProfiler

SUITE_NAME = "truck_delay_features"
context.add_or_update_expectation_suite(expectation_suite_name=SUITE_NAME)

def batch_request_for(df, label):
    '''Wrap an in-memory DataFrame as a GE RuntimeBatchRequest.'''
    return RuntimeBatchRequest(
        datasource_name="truck_delay_runtime",
        data_connector_name="default_runtime_data_connector_name",
        data_asset_name="truck_delay",
        runtime_parameters={"batch_data": df},
        batch_identifiers={"default_identifier_name": label},
    )

validator = context.get_validator(
    batch_request=batch_request_for(ref, "initial_profile"),
    expectation_suite_name=SUITE_NAME,
)

profiler = UserConfigurableProfiler(
    profile_dataset=validator,
    excluded_expectations=[
        # Drop the brittle statistical bounds — they fire on any new SAMPLE (sampling
        # variance), which is Evidently's job (Lab 2), not a schema contract. Keep the
        # durable schema/type/not-null/value-set rules that catch REAL corruption.
        "expect_column_quantile_values_to_be_between",
        "expect_column_min_to_be_between", "expect_column_max_to_be_between",
        "expect_column_mean_to_be_between", "expect_column_median_to_be_between",
        "expect_column_proportion_of_unique_values_to_be_between",
        "expect_column_stdev_to_be_between", "expect_column_sum_to_be_between",
        "expect_table_row_count_to_be_between",
    ],
    not_null_only=True,
)
suite = profiler.build_suite()
context.save_expectation_suite(suite, expectation_suite_name=SUITE_NAME)
print(f"Profiled {len(suite.expectations)} expectations across {ref.shape[1]} columns")
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Profiling:   0%|          | 0/37 [00:00<?, ?it/s, Column=route_avg_temp]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating an expectation suite with the following expectations:
#
# Table-Level Expectations
# expect_table_columns_to_match_ordered_list
# expect_table_row_count_to_be_between
#
# Expectations by Column
# Column Name: accident | Column Data Type: INT | Cardinality: TWO
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: age | Column Data Type: INT | Cardinality: FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: average_hours | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: average_speed_mph | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: avg_no_of_vehicles | Column Data Type: FLOAT | Cardinality: VERY_MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: delay | Column Data Type: INT | Cardinality: TWO
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_humidity | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_precip | Column Data Type: FLOAT | Cardinality: FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_pressure | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_temp | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_visibility | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_avg_wind_speed | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: dest_description | Column Data Type: STRING | Cardinality: FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: distance | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: driving_style | Column Data Type: STRING | Cardinality: VERY_FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: experience | Column Data Type: INT | Cardinality: FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: fuel_type | Column Data Type: STRING | Cardinality: VERY_FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: gender | Column Data Type: STRING | Cardinality: VERY_FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: is_midnight | Column Data Type: INT | Cardinality: TWO
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: load_capacity_pounds | Column Data Type: FLOAT | Cardinality: VERY_FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: mileage_mpg | Column Data Type: INT | Cardinality: VERY_FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_humidity | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_precip | Column Data Type: FLOAT | Cardinality: FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_pressure | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_temp | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_visibility | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_avg_wind_speed | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: origin_description | Column Data Type: STRING | Cardinality: FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: ratings | Column Data Type: INT | Cardinality: VERY_FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_humidity | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_precip | Column Data Type: FLOAT | Cardinality: VERY_FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_pressure | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_temp | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_visibility | Column Data Type: FLOAT | Cardinality: FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_avg_wind_speed | Column Data Type: FLOAT | Cardinality: MANY
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: route_description | Column Data Type: STRING | Cardinality: FEW
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Column Name: truck_age | Column Data Type: INT | Cardinality: VERY_FEW
# expect_column_max_to_be_between
# expect_column_mean_to_be_between
# expect_column_median_to_be_between
# expect_column_min_to_be_between
# expect_column_proportion_of_unique_values_to_be_between
# expect_column_values_to_be_in_set
# expect_column_values_to_be_in_type_list
# expect_column_values_to_not_be_null
#
#
# Profiled 273 expectations across 37 columns

# %% [markdown]
# ## Step 4 · Hand-edit — add the domain rules the profiler can't infer
# The profiler writes *empirical* bounds (e.g. `truck_age ∈ [1, 23]` because that's what it saw). We widen them to the
# *business* range so next year's 24-year-old truck doesn't trip a false alarm — and we add cross-column + enum rules.

# %%
v = context.get_validator(
    batch_request=batch_request_for(ref, "domain_rules"),
    expectation_suite_name=SUITE_NAME,
)

# Business range (not the empirical one the profiler inferred)
v.expect_column_values_to_be_between("truck_age", min_value=1, max_value=30, mostly=1.0)
v.expect_column_values_to_be_between("age", min_value=18, max_value=75, mostly=1.0)
v.expect_column_values_to_be_between("experience", min_value=0, max_value=60, mostly=1.0)

# Target must be binary
v.expect_column_distinct_values_to_be_in_set("delay", value_set=[0, 1])

# Categorical enums (note: 'Unknown' is a legal NaN-fill value from M3 Lab B)
v.expect_column_values_to_be_in_set("fuel_type", value_set=["diesel", "gas", "Unknown"])
v.expect_column_values_to_be_in_set("gender", value_set=["male", "female", "Unknown"])
v.expect_column_values_to_be_in_set("driving_style",
                                    value_set=["proactive", "conservative", "aggressive", "Unknown"])
v.expect_column_values_to_be_in_set("is_midnight", value_set=[0, 1])
v.expect_column_values_to_be_in_set("accident", value_set=[0, 1])

# Cross-column domain rule: a driver's experience can't exceed their age
v.expect_column_pair_values_a_to_be_greater_than_b(column_A="age", column_B="experience", or_equal=True, mostly=0.99)

v.save_expectation_suite(discard_failed_expectations=False)
suite = context.get_expectation_suite(SUITE_NAME)
print(f"Suite now has {len(suite.expectations)} expectations (profiled + hand-added domain rules)")
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Suite now has 278 expectations (profiled + hand-added domain rules)

# %% [markdown]
# ## Step 5 · Validate a CLEAN batch — the reference itself should pass ~100%

# %%
res_clean = context.get_validator(
    batch_request=batch_request_for(ref, "clean_validation"),
    expectation_suite_name=SUITE_NAME,
).validate()

print(f"Success:      {res_clean['success']}")
print(f"Expectations: {res_clean['statistics']['successful_expectations']}"
      f" / {res_clean['statistics']['evaluated_expectations']}")
print(f"Success %:    {res_clean['statistics']['success_percent']:.1f}")
# If <100%, a hand-edit over-tightened — loosen the offending range and re-run Step 4.
# Out:
# Calculating Metrics:   0%|          | 0/452 [00:00<?, ?it/s]
# Success:      False
# Expectations: 277 / 278
# Success %:    99.6

# %% [markdown]
# ## Step 6 · Build a deliberately CORRUPTED batch (the only synthetic part)

# %%
def make_corrupt_batch(reference: pd.DataFrame, n: int = 500, seed: int = 7) -> pd.DataFrame:
    '''Sample real rows and inject four classes of corruption GE should catch.'''
    b = reference.sample(n=n, random_state=seed).reset_index(drop=True).copy()
    b.loc[b.index[:25], "truck_age"] = -3                         # 1) out-of-range (negative)
    null_idx = b.sample(frac=0.05, random_state=1).index
    b.loc[null_idx, "ratings"] = np.nan                           # 2) NULL spike
    b.loc[b.index[300:310], "fuel_type"] = "hydrogen"             # 3) unknown category
    b.loc[b.index[400:402], "delay"] = 2                          # 4) target out of {0,1}
    return b

corrupt = make_corrupt_batch(ref)
print(f"Corrupted batch: {corrupt.shape}  (negative truck_age, null ratings, 'hydrogen' fuel, delay=2)")
# Out:
# Corrupted batch: (500, 37)  (negative truck_age, null ratings, 'hydrogen' fuel, delay=2)

# %% [markdown]
# ## Step 7 · Validate the corrupted batch — GE should fail with specific row-level errors

# %%
res_bad = context.get_validator(
    batch_request=batch_request_for(corrupt, "corrupted_validation"),
    expectation_suite_name=SUITE_NAME,
).validate()

print(f"Success: {res_bad['success']}")
print(f"Failed:  {res_bad['statistics']['unsuccessful_expectations']}"
      f" / {res_bad['statistics']['evaluated_expectations']}\n")
print("Failures:")
for r in res_bad["results"]:
    if not r["success"]:
        e = r["expectation_config"]
        col = e["kwargs"].get("column", e["kwargs"].get("column_A", "<table>"))
        unexpected = r["result"].get("unexpected_count", "?")
        sample = r["result"].get("partial_unexpected_list", [])[:3]
        print(f"  X {e['expectation_type']:42s} col={col:14s} unexpected={unexpected}  sample={sample}")
# Out:
# Calculating Metrics:   0%|          | 0/452 [00:00<?, ?it/s]
# Success: False
# Failed:  126 / 278
#
# Failures:
#   X expect_table_row_count_to_be_between       col=<table>        unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=route_avg_temp unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=route_avg_temp unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_temp unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=route_avg_temp unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_temp unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=route_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=route_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=route_avg_precip unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_precip unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_precip unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=route_avg_humidity unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=route_avg_humidity unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_humidity unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=route_avg_humidity unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_humidity unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=route_avg_visibility unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_visibility unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_visibility unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=route_avg_pressure unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=route_avg_pressure unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=route_avg_pressure unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_avg_pressure unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_temp unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=origin_avg_temp unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_temp unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=origin_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_precip unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_precip unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=origin_avg_humidity unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_humidity unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=origin_avg_humidity unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_humidity unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_visibility unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=origin_avg_visibility unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_visibility unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=origin_avg_pressure unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=origin_avg_pressure unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=origin_avg_pressure unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_avg_pressure unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=dest_avg_temp  unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_temp  unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=dest_avg_temp  unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_temp  unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=dest_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_wind_speed unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=dest_avg_precip unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_precip unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_precip unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=dest_avg_humidity unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=dest_avg_humidity unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_humidity unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=dest_avg_humidity unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_humidity unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=dest_avg_visibility unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_visibility unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=dest_avg_visibility unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_visibility unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=dest_avg_pressure unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=dest_avg_pressure unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=dest_avg_pressure unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=dest_avg_pressure unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_avg_pressure unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=truck_age      unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=truck_age      unexpected=?  sample=[]
#   X expect_column_values_to_be_in_set          col=truck_age      unexpected=25  sample=[-3, -3, -3]
#   X expect_column_proportion_of_unique_values_to_be_between col=truck_age      unexpected=?  sample=[]
#   X expect_column_values_to_be_between         col=truck_age      unexpected=25  sample=[-3, -3, -3]
#   X expect_column_mean_to_be_between           col=load_capacity_pounds unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=load_capacity_pounds unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=mileage_mpg    unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=mileage_mpg    unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=mileage_mpg    unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=mileage_mpg    unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=age            unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=age            unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=age            unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=age            unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=age            unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=experience     unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=experience     unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=experience     unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=experience     unexpected=?  sample=[]
#   X expect_column_values_to_be_between         col=experience     unexpected=5  sample=[-2, -7, -3]
#   X expect_column_max_to_be_between            col=average_speed_mph unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=average_speed_mph unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=average_speed_mph unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=average_speed_mph unexpected=?  sample=[]
#   X expect_column_min_to_be_between            col=avg_no_of_vehicles unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=avg_no_of_vehicles unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=avg_no_of_vehicles unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=avg_no_of_vehicles unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=avg_no_of_vehicles unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=distance       unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=distance       unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=distance       unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=distance       unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=average_hours  unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=average_hours  unexpected=?  sample=[]
#   X expect_column_median_to_be_between         col=average_hours  unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=average_hours  unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=route_description unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=origin_description unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=dest_description unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=accident       unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=accident       unexpected=?  sample=[]
#   X expect_column_values_to_be_in_set          col=fuel_type      unexpected=10  sample=['hydrogen', 'hydrogen', 'hydrogen']
#   X expect_column_proportion_of_unique_values_to_be_between col=fuel_type      unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=gender         unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=driving_style  unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=ratings        unexpected=?  sample=[]
#   X expect_column_values_to_not_be_null        col=ratings        unexpected=25  sample=[nan, nan, nan]
#   X expect_column_proportion_of_unique_values_to_be_between col=ratings        unexpected=?  sample=[]
#   X expect_column_values_to_be_in_type_list    col=ratings        unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=is_midnight    unexpected=?  sample=[]
#   X expect_column_proportion_of_unique_values_to_be_between col=is_midnight    unexpected=?  sample=[]
#   X expect_column_max_to_be_between            col=delay          unexpected=?  sample=[]
#   X expect_column_mean_to_be_between           col=delay          unexpected=?  sample=[]
#   X expect_column_values_to_be_in_set          col=delay          unexpected=2  sample=[2, 2]
#   X expect_column_proportion_of_unique_values_to_be_between col=delay          unexpected=?  sample=[]
#   X expect_column_distinct_values_to_be_in_set col=delay          unexpected=?  sample=[]

# %% [markdown]
# ## Step 8 · The structured failure payload (what Lab 4 / Lab 5 publish to SNS)

# %%
def ge_failure_payload(results) -> dict:
    '''Reduce a GE validation result to the compact dict the alerting pipeline sends.'''
    return {
        "success": bool(results["success"]),
        "evaluated": results["statistics"]["evaluated_expectations"],
        "passed": results["statistics"]["successful_expectations"],
        "failed": results["statistics"]["unsuccessful_expectations"],
        "success_percent": round(results["statistics"]["success_percent"], 1),
        "failures": [
            {
                "expectation": r["expectation_config"]["expectation_type"],
                "column": r["expectation_config"]["kwargs"].get("column"),
                "unexpected_count": r["result"].get("unexpected_count", 0),
                "sample": r["result"].get("partial_unexpected_list", [])[:3],
            }
            for r in results["results"] if not r["success"]
        ],
    }

import pprint; pprint.pp(ge_failure_payload(res_bad))
# Out:
# {'success': False,
#  'evaluated': 278,
#  'passed': 152,
#  'failed': 126,
#  'success_percent': 54.7,
#  'failures': [{'expectation': 'expect_table_row_count_to_be_between',
#                'column': None,
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'route_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'route_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'route_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'route_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'route_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'route_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'route_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'route_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'route_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'route_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'route_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'route_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'route_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'origin_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'origin_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'origin_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'origin_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'origin_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'origin_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'origin_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'origin_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'dest_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'dest_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_temp',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'dest_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_wind_speed',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'dest_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_precip',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'dest_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'dest_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'dest_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_humidity',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'dest_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'dest_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_visibility',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'dest_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'dest_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'dest_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'dest_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_avg_pressure',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'truck_age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'truck_age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_in_set',
#                'column': 'truck_age',
#                'unexpected_count': 25,
#                'sample': [-3, -3, -3]},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'truck_age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_between',
#                'column': 'truck_age',
#                'unexpected_count': 25,
#                'sample': [-3, -3, -3]},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'load_capacity_pounds',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'load_capacity_pounds',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'mileage_mpg',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'mileage_mpg',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'mileage_mpg',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'mileage_mpg',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'age',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'experience',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'experience',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'experience',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'experience',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_between',
#                'column': 'experience',
#                'unexpected_count': 5,
#                'sample': [-2, -7, -3]},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'average_speed_mph',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'average_speed_mph',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'average_speed_mph',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'average_speed_mph',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_min_to_be_between',
#                'column': 'avg_no_of_vehicles',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'avg_no_of_vehicles',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'avg_no_of_vehicles',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'avg_no_of_vehicles',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'avg_no_of_vehicles',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'distance',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'distance',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'distance',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'distance',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'average_hours',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'average_hours',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_median_to_be_between',
#                'column': 'average_hours',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'average_hours',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'route_description',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'origin_description',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'dest_description',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'accident',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'accident',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_in_set',
#                'column': 'fuel_type',
#                'unexpected_count': 10,
#                'sample': ['hydrogen', 'hydrogen', 'hydrogen']},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'fuel_type',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'gender',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'driving_style',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'ratings',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_not_be_null',
#                'column': 'ratings',
#                'unexpected_count': 25,
#                'sample': [nan, nan, nan]},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'ratings',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_in_type_list',
#                'column': 'ratings',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'is_midnight',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'is_midnight',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_max_to_be_between',
#                'column': 'delay',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_mean_to_be_between',
#                'column': 'delay',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_values_to_be_in_set',
#                'column': 'delay',
#                'unexpected_count': 2,
#                'sample': [2, 2]},
#               {'expectation': 'expect_column_proportion_of_unique_values_to_be_between',
#                'column': 'delay',
#                'unexpected_count': 0,
#                'sample': []},
#               {'expectation': 'expect_column_distinct_values_to_be_in_set',
#                'column': 'delay',
#                'unexpected_count': 0,
#                'sample': []}]}

# %% [markdown]
# ## Step 9 · Generate Data Docs — the team's HTML schema contract

# %%
context.build_data_docs()
docs = context.get_docs_sites_urls()
print("Data Docs built:")
for d in docs:
    print("  ", d["site_url"])
# Open that file:// URL in a browser. Expectations tab = the contract; Validation Results tab = run history.
# Out:
# Data Docs built:
#    file://c:\Users\prash\OneDrive\2026\Training\K21Academy\MLOps\Module 6\labs\gx\uncommitted/data_docs/local_site/index.html

# %% [markdown]
# ## Step 10 · Artifact chain — what downstream labs consume
# The committed output is **`great_expectations/expectations/truck_delay_features.json`** plus the project around it.
# **Lab 4** (combined exploration) and **Lab 5** (production script) load this exact suite by name and run it against each
# incoming batch *before* the Evidently drift check (GE is cheap → fail fast on schema).

# %%
suite_path = os.path.join(context.root_directory, "expectations", f"{SUITE_NAME}.json")
print("Suite persisted at:", suite_path, "->", os.path.exists(suite_path))
print("Pass this folder to Lab 4 / Lab 5 (they call context.get_validator(..., expectation_suite_name='truck_delay_features')).")
# Out:
# Suite persisted at: great_expectations\expectations\truck_delay_features.json -> False
# Pass this folder to Lab 4 / Lab 5 (they call context.get_validator(..., expectation_suite_name='truck_delay_features')).

# %% [markdown]
# ## GE vs Evidently — where to draw the line
# | | **Great Expectations** (this lab) | **Evidently** (Lab 2) |
# |---|---|---|
# | Question | "does this batch satisfy the schema contract?" | "is the distribution shifting over time?" |
# | Fires when | a *single* row violates a rule | statistical distance crosses a threshold |
# | Best for | schema breaks, type changes, NULL spikes, out-of-range | slow drifts, monsoon precip shift, fleet aging |
# | Misses | subtle statistical shifts | an all-NULL column (degenerate distribution) |
# | Cost | cheap (iterate rules) | ~1 s (Wasserstein on 30 cols × 1k rows) |
#
# **Rule of thumb:** if it would *break your code* → GE catches it. If it would *degrade your accuracy* → Evidently catches it.
#
# ## Verification Checklist
# - [ ] `great_expectations/` project created; `expectations/truck_delay_features.json` exists
# - [ ] Clean validation (reference) reports ~100% pass
# - [ ] Corrupted validation fails, naming `truck_age`, `ratings`, `fuel_type`, `delay`
# - [ ] `ge_failure_payload(...)` returns the compact failure dict
# - [ ] Data Docs HTML opens and shows the suite + both validation runs
# - [ ] You can state the GE-vs-Evidently difference in two sentences
#
# ## What's next — Lab 4
# You now have two independent monitors: an Evidently drift detector (Lab 2) and a GE validator (Lab 3). **Lab 4** fuses
# them into one flow — GE first (fail fast), then Evidently, then publish a structured alert to the **SNS topic from Lab 1**
# — and returns an exit code so it composes with cron / Airflow / EventBridge. **Lab 5** ships that flow as a production `.py`.
#
# ## Troubleshooting
# | Symptom | Fix |
# |---|---|
# | `ImportError: UserConfigurableProfiler` | GE v1 installed — pin `great-expectations>=0.18,<1.0` |
# | `len(suite.expectations) == 0` | the validator wasn't fed a real batch — confirm `runtime_parameters={"batch_data": ref}` |
# | "no datasource named ..." on validate | re-run Step 2 (the runtime datasource must be registered in this kernel) |
# | clean validation < 100% | a hand-edit over-tightened — widen the offending range in Step 4 |
# | `FileDataContext.create` errors "already exists" | fine — the `except` branch loads the existing project |
# | Data Docs "no validations to render" | run a validation (Step 5) before `build_data_docs()` |
